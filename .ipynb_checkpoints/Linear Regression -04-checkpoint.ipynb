# %% [markdown]
# Linear Regression

# %%
import pandas as pd
dict= {
    'name':["nayem","hamim","jakku bhai","abdul hamid"],
    "Occupassion":["Sub assistant engineer","Sub assistant engineer","operator","asst.manager"],
    "enroll":[541073,541075,541076,541089],
    "department":["Quality","production","production","mechanical"]
    
}
df = pd.DataFrame(dict)
df
# Out:
#           name             Occupassion  enroll  department
# 0        nayem  Sub assistant engineer  541073     Quality
# 1        hamim  Sub assistant engineer  541075  production
# 2   jakku bhai                operator  541076  production
# 3  abdul hamid            asst.manager  541089  mechanical

# %%
print(dict["name"])
# Out:
# dict['name']

# %%
# !pip install scikit-learn
# Out:
# ^C

# %%
import numpy as np
from sklearn.linear_model import linearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import numpy as np
# ----> 2 from sklearn.linear_model import linearRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import pandas as pd
table={
    "Weight" : [2,4,5,3,6,5,7],
    "Price" : [35,60,20,50,50,55,60]
}
df=pd.DataFrame(table)
df
# Out:
#    Weight  Price
# 0       2     35
# 1       4     60
# 2       5     20
# 3       3     50
# 4       6     50
# 5       5     55
# 6       7     60

# %%
# !pip install openpyxl
import pandas as pd
dn = pd.read_excel ("Total Order And present Stock.xlsx")
dn
# Out:
# ...
#                                  Akij Jute Mills Ltd.  \
# 0                          Akij City,Noapara, Jashore
# 1   Count Wise Order In Hands Against Daily Produc...
# 2                                                 NaN
# 3                                         Light Count
# 4                                               Count
# ..                                                ...
# 71                                           40/1 CRT
# 72                                    96/2 HESS (VOT)
# 73                                              Total
# 74                                                NaN
# 75                                        Grand Total
#
#                  Unnamed: 1    Unnamed: 2                Unnamed: 3  \
# 0                       NaN           NaN                       NaN
# 1                       NaN           NaN                       NaN
# 2                       NaN           NaN                       NaN
# ...
